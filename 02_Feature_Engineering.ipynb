# %% [markdown]
# <a href="https://colab.research.google.com/github/DDoS-W/TAIF/blob/main/02_Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TAIF - Trustworthy Agentic Investment Framework
#
# ## Module
# 02 - Feature Engineering
#
# ## Author
# SHENG HSU
#
# ## Version
# 0.1
#
# ## Last Update
# 2026-07-28
#
# ## Input
#
# data/raw/raw_2330_2024.csv
#
# ## Output
#
# data/processed/processed_2330_2024.csv
#
# ## Description
#
# Build financial features for LLM and Multi-Agent analysis.

# %%
##MOUNT

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
##IMPORTS

import sys
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
##CONFIG

# Project Root
PROJECT_ROOT = Path("/content/drive/MyDrive/TAIF")

# Python Path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# Data Folder
RAW_DATA = PROJECT_ROOT / "data" / "raw"
PROCESSED_DATA = PROJECT_ROOT / "data" / "processed"

print("Project Root:", PROJECT_ROOT)
# Out:
# Project Root: /content/drive/MyDrive/TAIF

# %%
##LOAD

csv_path = RAW_DATA / "raw_2330_2024.csv"

df = pd.read_csv(
    csv_path,
    index_col=0
)

print(df.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-02 00:00:00+08:00  567.474643  570.360107  566.512822  570.360107
# 2024-01-03 00:00:00+08:00  561.703791  562.665612  554.009218  555.932861
# 2024-01-04 00:00:00+08:00  557.856628  558.818450  554.971163  557.856628
# 2024-01-05 00:00:00+08:00  555.932921  557.856564  552.085634  554.009277
# 2024-01-08 00:00:00+08:00  559.780183  562.665648  556.894718  560.742004
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-01-02 00:00:00+08:00  26059058        0.0           0.0
# 2024-01-03 00:00:00+08:00  37106763        0.0           0.0
# 2024-01-04 00:00:00+08:00  15309129        0.0           0.0
# 2024-01-05 00:00:00+08:00  18158971        0.0           0.0
# 2024-01-08 00:00:00+08:00  17761275        0.0           0.0

# %%
print(df.info())

display(df.head())

display(df.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 242 entries, 2024-01-02 00:00:00+08:00 to 2024-12-31 00:00:00+08:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          242 non-null    float64
#  1   High          242 non-null    float64
#  2   Low           242 non-null    float64
#  3   Close         242 non-null    float64
#  4   Volume        242 non-null    int64
#  5   Dividends     242 non-null    float64
#  6   Stock Splits  242 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 15.1+ KB
# None
#                                  Open        High         Low       Close  \
# Date
# 2024-01-02 00:00:00+08:00  567.474643  570.360107  566.512822  570.360107
# 2024-01-03 00:00:00+08:00  561.703791  562.665612  554.009218  555.932861
# 2024-01-04 00:00:00+08:00  557.856628  558.818450  554.971163  557.856628
# ...

# %%
##PROCESS

from src.feature_builder import FeatureBuilder

builder = FeatureBuilder()

print("FeatureBuilder 載入成功")
# Out:
# FeatureBuilder initialized.
# FeatureBuilder 載入成功

# %%
feature_df = builder.build(df)

feature_df.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-02 00:00:00+08:00  567.474643  570.360107  566.512822  570.360107
# 2024-01-03 00:00:00+08:00  561.703791  562.665612  554.009218  555.932861
# 2024-01-04 00:00:00+08:00  557.856628  558.818450  554.971163  557.856628
# 2024-01-05 00:00:00+08:00  555.932921  557.856564  552.085634  554.009277
# 2024-01-08 00:00:00+08:00  559.780183  562.665648  556.894718  560.742004
#
#                              Volume  Dividends  Stock Splits         MA5  \
# Date
# 2024-01-02 00:00:00+08:00  26059058        0.0           0.0         NaN
# 2024-01-03 00:00:00+08:00  37106763        0.0           0.0         NaN
# 2024-01-04 00:00:00+08:00  15309129        0.0           0.0         NaN
# 2024-01-05 00:00:00+08:00  18158971        0.0           0.0         NaN
# 2024-01-08 00:00:00+08:00  17761275        0.0           0.0  559.780176
#
#                            MA20  DailyReturn  Volatility20  RSI14
# ...

# %%
##VALIDATION

feature_df.columns.tolist()
# Out:
# ['Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume',
#  'Dividends',
#  'Stock Splits',
#  'MA5',
#  'MA20',
#  'DailyReturn',
#  'Volatility20',
#  'RSI14']

# %%
feature_df[[
    "Close",
    "MA5",
    "MA20",
    "RSI14"
]].tail()
# Out:
#                                  Close          MA5         MA20      RSI14
# Date
# 2024-12-25 00:00:00+08:00  1061.257080  1046.585364  1035.134848  53.300720
# 2024-12-26 00:00:00+08:00  1061.257080  1049.519714  1039.235431  55.905474
# 2024-12-27 00:00:00+08:00  1066.147705  1060.279004  1044.019016  54.805413
# 2024-12-30 00:00:00+08:00  1066.147705  1062.235229  1046.902563  57.695265
# 2024-12-31 00:00:00+08:00  1051.475952  1061.257104  1048.078149  59.239042

# %%
##SAVE

output_file = PROCESSED_DATA / "processed_2330_2024.csv"

feature_df.to_csv(
    output_file,
    encoding="utf-8-sig"
)

print("Saved:", output_file)
# Out:
# Saved: /content/drive/MyDrive/TAIF/data/processed/processed_2330_2024.csv
