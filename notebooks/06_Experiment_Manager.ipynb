# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("/content/drive/MyDrive/TAIF")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from src.experiment_manager import ExperimentManager

# %%
manager = ExperimentManager(PROJECT_ROOT)
# Out:
# Experiment Manager initialized.

# %%
prompt = """
Test Prompt

Analyze TSMC.
"""

path = manager.save_prompt(prompt)

print(path)
# Out:
# /content/drive/MyDrive/TAIF/experiments/prompts/20260801_130335.txt

# %%
result = {

    "stock":"2330",

    "recommendation":"BUY",

    "confidence":90

}

path = manager.save_json(result)

print(path)
# Out:
# /content/drive/MyDrive/TAIF/experiments/outputs/20260801_130335.json
